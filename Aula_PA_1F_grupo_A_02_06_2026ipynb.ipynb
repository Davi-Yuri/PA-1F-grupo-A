# %% [markdown]
# <a href="https://colab.research.google.com/github/Davi-Yuri/PA-1F-grupo-A/blob/main/Aula_PA_1F_grupo_A_02_06_2026ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

a = random.random()

print (a)
# Out:
# 0.8792549687216016

# %%
import random

a = random.randint(0, 100)

print(a)
# Out:
# 67

# %%
#fazer um jogo de advinhação

#o usuario irá digitar um numero de 0 a 10 para adivinhar o numero secreto
#o usuário terá 03 tentativas para acertar o número
#o programa deverá imprimir uma mensagem se o palpite do usuário e maior ou menor que o número secreto
#o programa devera imprimir uma mensagem se o palpite do usuário e maior ou menor que o número secreto
#o programa deverá imprimir uma mensagem de quente,morno ou frio

#regras

#se a diferença do palpite para o número secreto for 3 - frio,2 -morno e 1 quente

import random
while esco != a:
  a = random.randint(0, 10)
  print(a)

  print("escolha um número de 0 a 10:")
  esco = input("qual numero vc acha que é? ")


  a3 = int(a - 3)
  a2 = int(a - 2)
  a1 = int(a - 1)
  A3 = int(a + 3)
  A2 = int(a + 2)
  A1 = int(a + 1)


if esco == a3 or A3:
    print("frio")
    print("tente novamente")
elif esco == a2 or A2:
    print("morno")
    print("tente novamente")
elif esco == a1 or A1:
    print("quente")
    print("tente novamente")
else:
    print("acertou!")
    break
# Out:
# 9
# escolha um número de 0 a 10:
# qual numero vc acha que é? 9
# 1
# escolha um número de 0 a 10:
# qual numero vc acha que é? 9
# 4
# escolha um número de 0 a 10:
# qual numero vc acha que é? 9
# 7
# escolha um número de 0 a 10:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21914/1176597664.py in <cell line: 0>()
#      17
#      18   print("escolha um número de 0 a 10:")
# ---> 19   esco = input("qual numero vc acha que é? ")
#      20
#      21
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
