# %% [markdown]
# <a href="https://colab.research.google.com/github/Davi-Yuri/PA-1F-grupo-A/blob/main/Aula_PA_1F_grupo_A_02_06_2026ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

a = random.random()

print (a)
# Out:
# 0.8792549687216016

# %%
import random

a = random.randint(0, 100)

print(a)
# Out:
# 67

# %%
# Fazer um jogo de adivinhação

# O usuário irá digitar um número de 0 a 10 para adivinhar o número secreto
# O usuário terá 03 tentativas para acertar o número
# O programa deverá imprimir uma mensagem se o palpite do usuário é maior ou menor que o número secreto
# O programa deverá imprimir uma mensagem de quente, morno ou frio

# Regras

# Se a diferença do palpite para o número secreto for 3 - frio, 2 - morno e 1 quente

import random

numero_secreto = random.randint(0, 10)
chances = 3

print("Bem-vindo ao jogo de adivinhação!")
print("Estou pensando em um número entre 0 e 10.")

for i in range(chances):
    try:
        guess = int(input(f"Tentativa {i + 1}/{chances}. Qual é o seu palpite? "))

        if not (0 <= guess <= 10):
            print("Por favor, digite um número entre 0 e 10.")
            continue

        if guess == numero_secreto:
            print(f"Parabéns! Você adivinhou o número secreto ({numero_secreto}) em {i + 1} tentativas!")
            break
        else:
            if guess < numero_secreto:
                print("Seu palpite é muito baixo.")
            else:
                print("Seu palpite é muito alto.")

            difference = abs(numero_secreto - guess)
            if difference == 1:
                print("Está quente.")
            elif difference == 2:
                print("Está morno.")
            elif difference >= 3:
                print("Está frio.")
    except ValueError:
        print("Entrada inválida. Por favor, digite um número inteiro.")

else:
    print(f"Suas tentativas acabaram! O número secreto era {numero_secreto}.")
# Out:
# Bem-vindo ao jogo de adivinhação!
# Estou pensando em um número entre 0 e 10.
# Tentativa 1/3. Qual é o seu palpite? 4
# Seu palpite é muito baixo.
# Está frio.
# Tentativa 2/3. Qual é o seu palpite? 7
# Seu palpite é muito baixo.
# Está morno.
# Tentativa 3/3. Qual é o seu palpite? 9
# Parabéns! Você adivinhou o número secreto (9) em 3 tentativas!
