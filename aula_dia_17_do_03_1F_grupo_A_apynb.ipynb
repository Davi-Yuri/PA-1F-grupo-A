# %% [markdown]
# <a href="https://colab.research.google.com/github/Davi-Yuri/PA-1F-grupo-A/blob/main/aula_dia_17_do_03_1F_grupo_A_apynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# operação aritimetica
# fazer um programa que calcula operações com 02 numeros

# Entrada

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))

# Processamento

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
div_int = a // b
resto = a % b
potencia = a ** b

# saída

print("")
print("-----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("--------------------------------SOMA--------------------------------")
print("")
print (f"o resultado da SOMA de {a} MAIS {b} é igual é: {soma} ")
print("")
print("")
print("-----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("------------------------------SUBTRAÇÃO-----------------------------")
print("")
print (f"o resultado da SUBTRAÇÃO de {a} MENOS {b} é igual é: {subtracao} ")
print("")
print("-----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("----------------------------MULTIPLICAÇÃO---------------------------")
print("")
print (f"o resultado da MULTIPLICAÇÃO de {a} MULTIPLICADO por {b} é igual é: {multiplicacao} ")
print("")
print("-----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("------------------------------DIVISÃO-------------------------------")
print("")
print (f"o resultado da DIVISÃO de {a} DIVIDIDO por {b} é igual é: {divisao} ")
print("")
print("---------------------------DIVISÃO INTEIRA--------------------------")
print("")
print (f"o resultado da DIVISÃO INTEIRA de {a} DIVIDIDO por {b} é igual é: {div_int} ")
print("")
print("---------------------------RESTO DA DIVISÃO-------------------------")
print("")
print (f"o resto da DIVISÃO de {a} DIVIDIDO por {b} é igual é: {resto} ")
print("")
print("-----------------------------POTENCIACÃO----------------------------")
print("")
print (f"o resultado da POTENCIA de {a} ELEVADO {b} é igual é: {potencia} ")
print("")
# Out:
# digite um numero: 4
# digite um numero: 2
#
# -----------------------OPERADORES ARITIMETICOS----------------------
#
# --------------------------------SOMA--------------------------------
#
# o resultado da SOMA de 4 MAIS 2 é igual é: 6
#
#
# -----------------------OPERADORES ARITIMETICOS----------------------
#
# ------------------------------SUBTRAÇÃO-----------------------------
#
# o resultado da SUBTRAÇÃO de 4 MENOS 2 é igual é: 2
#
# -----------------------OPERADORES ARITIMETICOS----------------------
#
# ----------------------------MULTIPLICAÇÃO---------------------------
#
# o resultado da MULTIPLICAÇÃO de 4 MULTIPLICADO por 2 é igual é: 8
#
# -----------------------OPERADORES ARITIMETICOS----------------------
#
# ------------------------------DIVISÃO-------------------------------
#
# o resultado da DIVISÃO de 4 DIVIDIDO por 2 é igual é: 2.0
#
# ---------------------------DIVISÃO INTEIRA--------------------------
#
# ...

# %%
# Operadores Relacionais

# Entrada

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))

# processamento

#comparação

igual = a == b

# saída

print(igual)
# Out:
# digite um numero: 2
# digite um numero: 2
# True

# %%
# Operadores Relacionais

# Entrada

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))

# processamento

#comparação

diferente = a != b

# saída
print(diferente)
# Out:
# digite um numero: 6
# digite um numero: 7
# True

# %%
# Operadores Relacionais

# Entrada

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))

# processamento

#comparação

maior = a > b
menor = a < b
maiorigual = a >= b
menorigual = a <= b

print(maior)
print(menor)
print(maiorigual)
print(menorigual)
# Out:
# digite um numero: 6
# digite um numero: 1
# True
# False
# True
# False

# %%
# Fazer um programa que converta a temperatura
# F= (c x 9/5) + 32

C = float(input("digite uma temperatura em celsius: "))

Resultado = (C * 9/5 ) + 32

print(f"{C} graus celsius equivale á {Resultado} graus fahrenheit")
# Out:
# digite uma temperatura em celsius: 12
# 12.0 graus celsius equivale á 53.6 graus fahrenheit

# %%
# fazer um programa que converte km em metros

km = float(input("digite um numero em KM: "))

Resultado = km * 1000

print(f"{km} kilometros equivale á {Resultado} metros")
# Out:
# digite um numero em KM: 1
# 1.0 kilometros equivale á 1000.0 metros

# %%
# Fazer um programa que converte horas em minutos

H = float(input("digite um numero em horas: "))

Resultado = H * 60

print(f"{H} horas equivale á {Resultado} minutos")
# Out:
# digite um numero em horas: 1
# 1.0 horas equivale á 60.0 minutos
