# %% [markdown]
# <a href="https://colab.research.google.com/github/Davi-Yuri/PA-1F-grupo-A/blob/main/Atividadeteams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 questão
n1 = 2
n2 = 2
resultado = n1 + n2
print(f"{n1} + {n2} = {resultado}")
# Out:
# 2 + 2 = 4

# %%
# 2 questão
n1 = 2
n2 = 3
resultado = n1 * n2
print(f"{n1} * {n2} = {resultado}")
# Out:
# 2 * 3 = 6

# %%
# 3 questão
n1 = int(input("coloque a primeira nota: "))
n2 = int(input("coloque a segunda nota: "))
resultado = n1 + n2
print(f"A média é {resultado}")
# Out:
# coloque a primeira nota: 5
# coloque a segunda nota: 4
# A média é 9

# %%
# 4 questão
n = int(input("coloque um numero: "))
dobro = n * 2
triplo = n * 3
print(f"O dobro de {n} é {dobro} e o triplo é {triplo}")
# Out:
# coloque um numero: 2
# O dobro de 2 é 4 e o triplo é 6

# %%
# 5 questão
valor = float(input("coloque o valor do produto: "))
quant = int(input("coloque a quantidade do produto: "))
valorT = valor * quant
print(f"o valor total do produto é R$ {valorT}")
# Out:
# coloque o valor do produto: 5
# coloque a quantidade do produto: 2
# o valor total do produto é R$ 10.0
