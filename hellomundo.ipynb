# %% [markdown]
# <a href="https://colab.research.google.com/github/Davi-Yuri/PA-1F-grupo-A/blob/main/hellomundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world")

print ("Please speed I need this")
# Out:
# hello world
# Please speed I need this

# %%
print ("My mom is kinda home less :( , I live with my dad, bro.")
# Out:
# My mom is kinda home less :( , I live with my dad, bro.

# %%
Nome = input("qual o seu nome? ")
idade = input("qual a sua idade? ")
Nível_de_viadagem = input("Você é gay? :/ ")
input("Parabéns, tu é viado!!!")
# Out:
# qual o seu nome? njuj
# qual a sua idade? uhi
# Você é gay? :/ jiji
# Parabéns, tu é viado!!!Obrigado.
# 'Obrigado.'
