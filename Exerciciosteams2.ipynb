# %% [markdown]
# <a href="https://colab.research.google.com/github/Davi-Yuri/PA-1F-grupo-A/blob/main/Exerciciosteams2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# questão 1
nome = input("qual o seu nome: ")
print(type(nome))
idade = int(input("qual a sua idade: "))
print(type(idade))
altura = float(input("qual a sua altura: "))
print(type(altura))
nota = float(input("qual a sua nota: "))
print(type(nota))
cidade = input("qual a sua cidade: ")
print(type(cidade))
# Out:
# qual o seu nome: Davi
# <class 'str'>
# qual a sua idade: 15
# <class 'int'>
# qual a sua altura: 1.60
# <class 'float'>
# qual a sua nota: 10
# <class 'float'>
# qual a sua cidade: Xique Xique Bahia
# <class 'str'>

# %%
# questão 2
n1 = 7.5
n2 = 8.0
n3 = 6.5
soma = n1 + n2 + n3
media = soma / 3
mediaR = round(media, 1)
print(f"a media é {mediaR}")
# Out:
# a media é 7.3

# %%
# questão 3
t1 = "20"
t2 = "3.5"
n = 8

a = int(t1)
soma = a + 10
print(soma)

b = float(t2)
mult = b * 2
print(mult)

c = str(n)
anos = "anos"
palavra = c + anos
print(palavra)
# Out:
# 30
# 7.0
# 8anos

# %%
# questão 4
n1 = 15 * 2
print(f"15 * 2 = {n1}")

n2 = 90 / 2
print(f"90 / 2 = {n2}")

n3 = 17 % 5
print(f"17 % 5 = {n3}")

n4 = 2 ** 4
print(f"2 ** 4 = {n4}")

m1 = 10
m2 = 8
m3 = 6
mf = m1 + m2 + m3
n5 = mf / 3
print(f"(10 + 8 + 6) /3 = {n5}")
# Out:
# 15 * 2 = 30
# 90 / 2 = 45.0
# 17 % 5 = 2
# 2 ** 4 = 16
# (10 + 8 + 6) /3 = 8.0

# %%
# questão 5
idade = 16
nota = 8.5
preço = 45.0

print(idade >= 18)
print(nota > 7)
print(preço <= 50)
print(idade == 16)
print(nota != 10)
# Out:
# False
# True
# True
# True
# True

# %%
# questão 6
produto = 80.00
descon = 0.10
valorf = float(produto * descon)

print(f"o desconto é {descon}")
print(f"o valor final é {valorf}")
print(produto < 75.00)
# Out:
# o desconto é 0.1
# o valor final é 8.0
# False

# %%
# questão 7
nome = input("qual o nome do aluno? ")
n1 = float(input("qual a primeira nota dele? "))
n2 = float(input("qual a segunda nota dele? "))
media = n1 + n2
mediaf = media / 2
print(f"O aluno {nome} tirou média {mediaf}")
# Out:
# qual o nome do aluno? Davi
# qual a primeira nota dele? 8
# qual a segunda nota dele? 7
# O aluno Davi tirou média 7.5
