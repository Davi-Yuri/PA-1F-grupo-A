# %% [markdown]
# <a href="https://colab.research.google.com/github/Davi-Yuri/PA-1F-grupo-A/blob/main/atividade_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escrever um programa que o usuário digita um número de 1 a 10 e o programa impri a tabuada do número digitado.

n = int (input("escolha um numero de 1 a 10: "))

for i in range (1):
  print(f"{n} X {i} = {n *1}")

for i in range (1):
   print(f"{n} X {i} = {n *2}")

for i in range (1):
   print(f"{n} X {i} = {n *3}")

for i in range (1):
   print(f"{n} X {i} = {n *4}")

for i in range (1):
   print(f"{n} X {i} = {n *5}")

for i in range (1):
   print(f"{n} X {i} = {n *6}")

for i in range (1):
   print(f"{n} X {i} = {n *7}")

for i in range (1):
   print(f"{n} X {i} = {n *8}")

for i in range (1):
   print(f"{n} X {i} = {n *9}")

for i in range (1):
   print(f"{n} X {i} = {n *10}")
# Out:
# escolha um numero de 1 a 10: 2
# 2 X 0 = 2
# 2 X 0 = 4
# 2 X 0 = 6
# 2 X 0 = 8
# 2 X 0 = 10
# 2 X 0 = 12
# 2 X 0 = 14
# 2 X 0 = 16
# 2 X 0 = 18
# 2 X 0 = 20

# %%
 # 1 - Escrever um programa que o usuário digita um número e o programa imprimi até o número digitado.

n = int (input("escolha um numero: "))

for i in range (n):
  print(i + 1)
# Out:
# escolha um numero: 5
# 1
# 2
# 3
# 4
# 5

# %%
# 2 - Escrever um programa que o usuário digita um número e o programa imprimi o número digitado até o zero (contagem regressiva).

n = int (input("escolha um numero: "))

for i in range (n):
  print(i + n)
# Out:
# escolha um numero: 7
# 7
# 8
# 9
# 10
# 11
# 12
# 13

# %%
# 3 - Escrever um programa que o usuário digita um número e o programa imprimi os números pares.

n = int(input("escolha um numero: "))
par = n * 2

for i in range (n - 3):
  print(i * 2)
# Out:
# escolha um numero: 7
# 0
# 2
# 4
# 6

# %%
# 4 - Escrever um programa que o usuário digita um número e o programa imprimi os números impares.

n = int(input("escolha um numero: "))

for i in range (n + 1):

      if i % 2 !=0:
        print(i)
# Out:
# escolha um numero: 10
# 1
# 3
# 5
# 7
# 9

# %%
# 5 - Escrever um programa que o usuário digita um número e programa soma os números até o número digitado.

n = int(input("escolha um numero: "))
soma = 0

for i in range (n):
  soma = i + soma

print(soma)
# Out:
# escolha um numero: 4
# 0
# 1
# 3
# 6

# %%
# 6 - Escrever um programa que o usuário digita uma palavra e o programa conta as letras da palavra.

palavra = (input("escolha uma palavra: "))
quant = 0

for i in (palavra):
  quant += +1
  print(quant)
# Out:
# escolha uma palavra: oi
# 1
# 2

# %%
# 7 - Escrever um programa que o usuário digita uma palavra e o programa conta as vogais da palavra.

# %%
# 8 - Escrever um programa que o usuário digita uma palavra e o programa imprimi a palavra invertida.

# %%
# 9 - Escrever um programa que o usuário digita 04 números e o programa imprimi o maior.
